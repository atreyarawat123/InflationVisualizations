# %%
import pandas as pd
import numpy as np 
import matplotlib.pylab as plt

# %%
inf = pd.read_csv("inflation.csv")

# %%
inf.head(10)
# Out:
#          DATE  CPIFABSL
# 0  1967-01-01      34.8
# 1  1967-02-01      34.7
# 2  1967-03-01      34.7
# 3  1967-04-01      34.6
# 4  1967-05-01      34.6
# 5  1967-06-01      34.9
# 6  1967-07-01      35.0
# 7  1967-08-01      35.2
# 8  1967-09-01      35.2
# 9  1967-10-01      35.3

# %%
inf[100:130]
# Out:
#            DATE  CPIFABSL
# 100  1975-05-01      59.0
# 101  1975-06-01      59.6
# 102  1975-07-01      60.6
# 103  1975-08-01      60.7
# 104  1975-09-01      61.0
# 105  1975-10-01      61.6
# 106  1975-11-01      62.0
# 107  1975-12-01      62.3
# 108  1976-01-01      62.2
# 109  1976-02-01      61.6
# 110  1976-03-01      61.3
# 111  1976-04-01      61.3
# 112  1976-05-01      61.6
# 113  1976-06-01      61.7
# 114  1976-07-01      62.0
# 115  1976-08-01      62.2
# 116  1976-09-01      62.5
# 117  1976-10-01      62.8
# 118  1976-11-01      62.8
# 119  1976-12-01      62.9
# 120  1977-01-01      63.1
# 121  1977-02-01      64.2
# 122  1977-03-01      64.5
# 123  1977-04-01      65.2
# 124  1977-05-01      65.5
# 125  1977-06-01      65.9
# 126  1977-07-01      66.1
# 127  1977-08-01      66.4
# 128  1977-09-01      66.6
# 129  1977-10-01      66.8

# %%
inf.columns
# Out:
# Index(['DATE', 'CPIFABSL'], dtype='object')

# %%
inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DATE      652 non-null    object
#  1   CPIFABSL  652 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 10.3+ KB

# %%
inf[400:405]
# Out:
#            DATE  CPIFABSL
# 400  2000-05-01     167.8
# 401  2000-06-01     168.0
# 402  2000-07-01     168.8
# 403  2000-08-01     169.3
# 404  2000-09-01     169.4

# %%
inf[inf['CPIFABSL']>=165]
# Out:
#            DATE  CPIFABSL
# 392  1999-09-01   165.100
# 393  1999-10-01   165.500
# 394  1999-11-01   165.800
# 395  1999-12-01   166.000
# 396  2000-01-01   166.100
# ..          ...       ...
# 647  2020-12-01   270.015
# 648  2021-01-01   270.212
# 649  2021-02-01   270.604
# 650  2021-03-01   270.946
# 651  2021-04-01   271.933
#
# [260 rows x 2 columns]

# %%
inf.sort_values(by = 'CPIFABSL', ascending = False)[:5]
# Out:
#            DATE  CPIFABSL
# 651  2021-04-01   271.933
# 650  2021-03-01   270.946
# 649  2021-02-01   270.604
# 648  2021-01-01   270.212
# 647  2020-12-01   270.015

# %%
inf['CPIFABSL'].hist()

# %%
plt.plot(inf['DATE'], inf['CPIFABSL'],'o', alpha = 0.7)
plt.xlabel('Date')
plt.ylabel('CPIFABSL')
# Out:
# Text(0, 0.5, 'CPIFABSL')

# %%
inf['change'] = inf.groupby(["DATE"])['CPIFABSL'].diff()

# %%
inf.head(20)
# Out:
#           DATE  CPIFABSL  change
# 0   1967-01-01      34.8     NaN
# 1   1967-02-01      34.7     NaN
# 2   1967-03-01      34.7     NaN
# 3   1967-04-01      34.6     NaN
# 4   1967-05-01      34.6     NaN
# 5   1967-06-01      34.9     NaN
# 6   1967-07-01      35.0     NaN
# 7   1967-08-01      35.2     NaN
# 8   1967-09-01      35.2     NaN
# 9   1967-10-01      35.3     NaN
# 10  1967-11-01      35.4     NaN
# 11  1967-12-01      35.5     NaN
# 12  1968-01-01      35.5     NaN
# 13  1968-02-01      35.7     NaN
# 14  1968-03-01      35.8     NaN
# 15  1968-04-01      36.0     NaN
# 16  1968-05-01      36.1     NaN
# 17  1968-06-01      36.1     NaN
# 18  1968-07-01      36.2     NaN
# 19  1968-08-01      36.3     NaN

# %%
inf.head()
